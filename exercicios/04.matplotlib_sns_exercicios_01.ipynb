# %% [markdown]
# # Exercicios matplotlib/seaborn

# %% [markdown]
# Antes de comenzar facemos as importacións necesarias:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Imos traballar co dataset **penguins**. O primeiro paso é crear un **DataFrame** a partir do mesmo:

# %%
import pandas as pd
df_penguins = pd.read_csv(r"C:\Users\BRAIS\Desktop\FPADISTANCIA\BD\analise-datos-pandas-main\analise-datos-pandas-main\data\penguins.csv")
display(df_penguins)
df_penguins["tipo"]="pinguino"
display(df_penguins)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 import pandas as pd
# ----> 2 df_penguins = pd.read_csv(r"C:\Users\BRAIS\Desktop\FPADISTANCIA\BD\analise-datos-pandas-main\analise-datos-pandas-main\data\penguins.csv")
#       3 display(df_penguins)
#       4 df_penguins["tipo"]="pinguino"
#
# ...

# %% [markdown]
# **Nota**: Os parámetros non especificados, por exemplo `figsize` poden configurarse ao gusto.
#
# **Exercicio 1**. Crea un gráfico de liñas que relacione a lonxitude do peteiro (`bill_length_mm`) coa profundidade (`bill_depth_mm`) para a especie (`species`) *'Adelie`*. Ordena por lonxitude do peteiro e establece título para as gráficas e os dous eixos (0,8 ptos).

# %%
# Solución aquí
df_adelie = df_penguins[df_penguins['species'] == 'Adelie'].sort_values('bill_length_mm')
plt.figure(figsize=(10, 6))
plt.plot(df_adelie['bill_length_mm'], df_adelie['bill_depth_mm'])
plt.title('Relación Longitud vs Profundidad (Adelie)')
plt.xlabel('Lonxitude do peteiro (mm)')
plt.ylabel('Profundidade do peteiro (mm)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Solución aquí
# ----> 2 df_adelie = df_penguins[df_penguins['species'] == 'Adelie'].sort_values('bill_length_mm')
#       3 plt.figure(figsize=(10, 6))
#       4 plt.plot(df_adelie['bill_length_mm'], df_adelie['bill_depth_mm'])
#
# NameError: name 'df_penguins' is not defined

# %% [markdown]
# **Exercicio 2**. Representa a relación entre a lonxitude do peteiro (*bill_length_mm*) e a profundidade do peteiro (*bill_depth_mm*) (0,8 ptos).

# %%
# Solución aquí

# %% [markdown]
# **Exercicio 3**. Modifica o exerciio anterior empregando **seaborn** e engadindo `hue='species` para diferenciar especies por cor (0,8 ptos).

# %%
# Solución aquí

# %% [markdown]
# **Exercicio 4**. Calcula o **peso medio** (*body_mass_g*) por especie e represéntao nun gráfico de barras (0,8 ptos).

# %%
# Solución aquí

# %% [markdown]
# **Exercicio 5**. Debuxa unha figura con dous gráficos (0,8 ptos):
# - un *histograma* da lonxitude das ás (*flipper_length_mm*) para todas as especies.
# - un *histograma* da lonxitude das ás (*flipper_length_mm*) para todas as especies separando por especies.

# %%
# Solución aquí

# %% [markdown]
# **Exericio 6**. Compara a distribución do peso corporal (*body_mass_g*) por sexo dentro de cada especie usando **boxplots** e **violinplots**. Crea unha figura con dous gráficos (0,8 ptos).

# %%
# Solución aquí

# %% [markdown]
# **Exercicio 7**. Empregando **Seaborn** crea un pairplot coas variables numéricas e colorea segundo a especie. O tipo ten que ser `kde`, agás na diagnoal que será de tipo `hist` (0,8 ptos).

# %%
# Solución aquí

# %% [markdown]
# **Exercicio 8**. Debuxa unha función ECDF **empregando só matplotlib** para a lonxitude do peteiro (bill_length_mm) (0,8 ptos).

# %%
# Solución aquí

# %% [markdown]
# **Exercicio 9**. Debuxa unha función ECDF para a lonxitude do peteiro (bill_length_mm) (0,8 ptos).

# %%
# Solución aquí

# %% [markdown]
# **Exercicio 10**. Crea unha grella con tres gráficos nunha fila (1 pto):
# - A primeira será un **histograma** sobre o peso (`body_mass_g`) agrupando en bloques de 20.
# - A segunda será un **kdeplot** sobre o peso (`body_mass_g`).
# - A terceira será un **ecdfplot** tamén sobre o peso.

# %%
## Solución aquí

# %% [markdown]
# **Exercicio 11**. Crea unha unha distribución sobre `body_mass_g` seguindo as seguintes instrucións (1 pto):
# - Agrupa en columnas por illa (`island`).
# - Agrupa por cores segundo a especie (`species`).
# - O tipo de gráfico será *kde*.
# - Os tres `subplots` estarán na mesma fila.

# %%
# Solución aquí

# %% [markdown]
# **Exercicio 12**. Crea un **heatmap** que amose as correlacións entre as variables numéricas. Emprega a función `select_dtypes` para quedarte só coas de tipo `'number'` e calcula a *correlación* con `cor()` (0,8).

# %%
# Solución aquí

# %% [markdown]
# ### Rúbricas
# - **Exercicios 1, 2, 3, 4, 5, 6, 7, 8, 9 e 12**
#
# | **Criterio**                             | **Nivel baixo (0 puntos)**                                                                                                 | **Nivel medio (0,4 puntos)**                                                                                                             | **Nivel alto (0,8 puntos)**                                                                                                                                                                      |
# | ---------------------------------------- | -------------------------------------------------------------------------------------------------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Corrección e completitude do gráfico** | O gráfico está ausente, non se executa ou é incorrecto. | O gráfico é visible e correcto pero falta algún parámetro (título, etiquetas...). | O gráfico está completo e correctamente configurado. |
#
#
# - **Exercicios 10 e 11**
#
# | **Criterio**                             | **Nivel baixo (0 puntos)**                                                                                                 | **Nivel medio (0,5 puntos)**                                                                                                             | **Nivel alto (1 punto)**                                                                                                                                                                      |
# | ---------------------------------------- | -------------------------------------------------------------------------------------------------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Corrección e completitude do gráfico** | O gráfico está ausente, non se executa ou é incorrecto. | O gráfico é visible e correcto pero falta algún parámetro (título, etiquetas...). | O gráfico está completo e correctamente configurado. |
