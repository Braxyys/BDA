# %% [markdown]
# # Laboratorio de repaso: Netflix – Bronze → Silver → Gold
#
#
# Dataset: `netflix_titles.csv` (Kaggle).
# As rutas están pensadas para unha estrutura de directorios:
# `data/bronze`, `data/silver`, `data/gold`.

# %% [markdown]
# ## 1. BRONZE – Carga do conxunto de datos
# **Enunciado:**
# 1. Carga o dataset dende `data/bronze/netflix_titles.csv` usando `pandas.read_csv`.
# 2. Amosar:
#    - número de filas e columnas,
#    - nomes das columnas,
#    - as 5 primeiras filas.
# 3. Garda unha copia *tal cal* (sen limpar) en formato Parquet en
#    `data/bronze/netflix_raw.parquet`.

# %%
# SOLUCIÓN
import pandas as pd
base_dir = '/home/jovyan/work/data'
# 1. Carga do CSV orixinal (bronze)

# 2. Información básica


# 3. Gardar copia raw en Parquet

# %% [markdown]
# ## 2. SILVER – Limpeza e estandarización
# **Enunciado:**
# Imos preparar unha versión "silver" máis limpa do catálogo:
#
# 1. Elimina filas onde falte información clave en `type`, `title` ou `release_year`.
# 2. Converte `date_added` a tipo `datetime` (pode haber nulos; mantelos como tal).
# 3. Crea unha nova columna `year_added` co ano no que se engadiu o título a Netflix.
# 4. Na columna `country`, queda só co **primeiro país** da lista (se hai varios separados por comas, colle o primeiro e elimina espazos sobrantes).
# 5. Estandariza os nomes das columnas a formato `snake_case`:
#    - todo en minúsculas,
#    - espazos substituídos por guión baixo `_`.
# 6. Garda o resultado limpo en `data/silver/netflix_clean.parquet`.

# %%
# SOLUCIÓN
# 1. Eliminamos filas con campos clave nulos


# 2. Convertemos date_added a datetime (permitindo erros)

# 3. Nova columna year_added

# 4. Primeiro país na columna country

# 5. Estandarizamos nomes de columnas a snake_case


# 6. Gardamos en silver

# %% [markdown]
# ## 3. GOLD – Transformacións agregadas
# **Enunciado:**
# Usando o DataFrame limpo (`df_silver`), imos crear tres vistas agregadas para o noso directorio **gold**:
#
# 1. **Número de títulos por ano de incorporación (`year_added`) e tipo (`type`)**.
# 2. **Top 15 países con maior número de títulos no catálogo**.
# 3. **Top 15 categorías/xéneros (`listed_in`) por número de títulos**. Para isto:
#    - divide `listed_in` en varias filas (explosión) separando por comas,
#    - elimina espazos sobrantes arredor das etiquetas.
#
# Garda cada resultado como Parquet en:
# - `data/gold/titles_per_year_type.parquet`
# - `data/gold/top_countries.parquet`
# - `data/gold/top_genres.parquet`

# %%
# SOLUCIÓN
# 1. Número de títulos por ano engadido e tipo


# 2. Top 15 países por número de títulos


# 3. Top 15 categorías/xéneros (listed_in)


# Gardamos en gold

# %% [markdown]
# ## 4. GOLD – Visualizacións
# **Enunciado:** Crea 3 gráficos usando `matplotlib` a partir dos DataFrames gold:
#
# 1. **Gráfico de liñas múltiple**: número de títulos engadidos por ano, con dúas liñas ("Movie" e "TV Show").
# 2. **Gráfico de barras horizontais** co top 15 de países por número de títulos.
# 3. **Gráfico múltiple (2 subplots)**:
#    - Subplot 1: top 15 xéneros/categorías (barra vertical) por número de títulos.
#    - Subplot 2: comparación entre películas e series no total do catálogo (barra).

# %%
# SOLUCIÓN
import matplotlib.pyplot as plt

# 1) Liñas múltiples: títulos por ano e tipo

# %%
# 2) Barras horizontais: top 15 países

# %%
# 3) Gráfico múltiple: xéneros + distribución Movie/TV Show

# Subplot 1: top 15 xéneros/categorías


# Subplot 2: distribución Movie vs TV Show no catálogo
