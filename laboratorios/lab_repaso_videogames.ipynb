# %% [markdown]
# # Laboratorio de repaso: Video Games Sales – Bronze → Silver → Gold
#
# Dataset: `vgsales.csv` (VGChartz / Kaggle).
# As rutas están pensadas para unha estrutura de directorios:
# `data/bronze`, `data/silver`, `data/gold`.

# %% [markdown]
# ## 1. BRONZE – Carga do conxunto de datos
# **Enunciado:**
# 1. Carga o dataset dende `data/bronze/vgsales.csv` usando `pandas.read_csv`.
# 2. Amosar:
#    - número de filas e columnas,
#    - nomes das columnas,
#    - as 5 primeiras filas.
# 3. Garda unha copia *tal cal* (sen limpar) en formato Parquet en
#    `data/bronze/raw.parquet`.

# %%
import pandas as pd

base_dir = '/home/jovyan/work/data'
# SOLUCIÓN


# 1. Carga do CSV orixinal (bronze)


# 2. Información básica


# 3. Gardar copia raw en Parquet

# %% [markdown]
# ## 2. SILVER – Limpeza e estandarización
# **Enunciado:**
# 1. Elimina as filas onde `Year` ou `Genre` estean baleiras (`NaN`).
# 2. Converte a columna `Year` a enteira (`int`).
# 3. Estandariza os nomes das columnas a formato `snake_case`:
#    - todo en minúsculas,
#    - espazos substituídos por guión baixo `_`.
# 4. Garda o resultado limpo en `data/silver/vgsales_clean.parquet`.

# %%
# SOLUCIÓN
# 1. Eliminamos filas con Year ou Genre nulos


# 2. Convertemos Year a int


# 3. Estandarizamos nomes de columnas a snake_case


# 4. Gardamos en silver

# %% [markdown]
# ## 3. GOLD – Transformacións agregadas
# **Enunciado:**
# Usando o DataFrame limpo (`df_silver`):
#
# 1. Calcula o **top 10 de plataformas por vendas globais** (`global_sales`).
# 2. Calcula as **vendas globais por ano**.
# 3. Calcula as **vendas medias por xénero**.
#
# Garda cada resultado como Parquet en:
# - `data/gold/top_platforms.parquet`
# - `data/gold/sales_per_year.parquet`
# - `data/gold/mean_sales_per_genre.parquet`

# %%
# SOLUCIÓN
# 1. Top 10 plataformas por vendas globais


# 2. Vendas globais por ano

# 3. Vendas medias por xénero

# 4. Gardamos en gold

# %% [markdown]
# ## 4. GOLD – Visualizacións
# **Enunciado:** Crea 3 gráficos usando `matplotlib`:
#
# 1. **Gráfico de barras horizontais** co top 10 de plataformas por vendas globais.
# 2. **Gráfico de liñas** coas vendas globais por ano.
# 3. **Gráfico múltiple (2 subplots)**:
#    - Subplot 1: vendas medias por xénero (barra).
#    - Subplot 2: número de xogos por xénero (conta de filas por xénero).

# %%
# SOLUCIÓN
import matplotlib.pyplot as plt

# 1) Barras horizontais: top 10 plataformas

# %%
# 2) Liña: vendas globais por ano

# %%
# 3) Gráfico múltiple: media de vendas por xénero + número de xogos por xénero


# Subplot 1: media de vendas por xénero


# Subplot 2: número de xogos por xénero
